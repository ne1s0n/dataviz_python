# %% [markdown]
# ---
#
# ## ASSIGNMENT! (formatting)
#
# You need to become familiar with markdown. Create a text cell that contains:
#
# * two separate paragraphs of text
# * a numbered list
# * a link to your favourite website
# * a small table with two columns and seven rows

# %% [markdown]
# ---
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
#
# Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
#
# 1. this is
# 2. my numbered
# 3. list of stuff
#
# [This is my favourite website](https://xkcd.com/)
#
# | Day       | Planet  |
# |-----------|:-------:|
# | Sunday    | Sun     |
# | Monday    | Moon    |
# | Tuesday   | Mars    |
# | Wednesday | Mercury |
# | Thursday  | Jupiter |
# | Friday    | Venus   |
# | Saturday  | Saturn  |
#
# ---

# %% [markdown]
# ---
#
# ## ASSIGNMENT! (image)
#
# Create a text cell with an embedded image of your choice taken from the internet.
#
# ---
#
# ![img](https://raw.githubusercontent.com/ne1s0n/dataviz_python/main/resources/bad_charts/bubbles.jpg)
#
# <img src="https://raw.githubusercontent.com/ne1s0n/dataviz_python/main/resources/bad_charts/bubbles.jpg" width = "100">
#
#
# ---

# %% [markdown]
# ---
#
# ## OPTIONAL ASSIGNMENT! (fancy list)
#
# Markdown doesn't support ordered lists that use letters instead of numbers. In other words the list will always go 1, 2, 3, ... and never A, B, C...
#
# Find the HTML code to do that!

# %% [markdown]
# ---
#
# <ol type="A">
#   <li> stands for Ant </li>
#   <li> stands for Baboon </li>
#   <li> stands for Cat </li>
# </ol>
#
# ---
